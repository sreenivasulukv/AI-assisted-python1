# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenivasulukv/AI-assisted-python1/blob/main/python_workshop_inb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Day-1***

# %%
import keyword
print("standard keyword",len(keyword.kwlist))
print("soft keywords=", keyword.softkwlist)
print("all keyword=", keyword.kwlist)
# Out:
# standard keyword 35
# soft keywords= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Python Data Types
#
# In Python, data types are used to classify data and determine the operations that can be performed on them. Here are some common built-in data types and how to print their types.

# %%
# Integer
num_int = 10
print(f"Value: {num_int}, Type: {type(num_int)}\n")

# Float
num_float = 10.5
print(f"Value: {num_float}, Type: {type(num_float)}\n")

# String
text_str = "Hello, Python!"
print(f"Value: '{text_str}', Type: {type(text_str)}\n")

# List
list_data = [1, 2, 3]
print(f"Value: {list_data}, Type: {type(list_data)}\n")

# Tuple
tuple_data = (1, 2, 3)
print(f"Value: {tuple_data}, Type: {type(tuple_data)}\n")

# Dictionary
dict_data = {'a': 1, 'b': 2}
print(f"Value: {dict_data}, Type: {type(dict_data)}\n")

# Boolean
bool_data = True
print(f"Value: {bool_data}, Type: {type(bool_data)}\n")
# Out:
# Value: 10, Type: <class 'int'>
#
# Value: 10.5, Type: <class 'float'>
#
# Value: 'Hello, Python!', Type: <class 'str'>
#
# Value: [1, 2, 3], Type: <class 'list'>
#
# Value: (1, 2, 3), Type: <class 'tuple'>
#
# Value: {'a': 1, 'b': 2}, Type: <class 'dict'>
#
# Value: True, Type: <class 'bool'>

# %%
y1 = 2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))
y3=str(y1)
print(y3)
print(type(y3))

y1=int(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)
print(type(y1))
print(type(y2))
print(type(y3))
c=50
d=float(c)
print(d)
print(type(d))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 50.0
# <class 'float'>

# %%
myname='sreenu'
my_dep='physics'
_my_university="sru"
MYLOC='HYD'
MYDEP2="BASIC SCIENCE"

print(myname)
print(my_dep)
print(_my_university)
print(MYLOC)
print(MYDEP2)
# Out:
# sreenu
# physics
# sru
# HYD
# BASIC SCIENCE

# %%
a=input("enter a value")
b=input("enter b value")
a=int(a)
b=int(b)
print("==================")
print("sample caluculator")
print("==================")
print("addition=",a+b)
print("multiplicatiom=",a*b)
print("==============")
# Out:
# enter a value10
# enter b value20
# ...
# sample caluculator
# ...
# addition= 30
# multiplicatiom= 200
# ...
