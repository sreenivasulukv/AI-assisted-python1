# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenivasulukv/AI-assisted-python1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 1   #Initialize variable
while(i<=5):    #while (condition):
  print("HELLO SRU") #code that wanted to repet
  i=i+1 #increment variable value
# Out:
# HELLO SRU
# HELLO SRU
# HELLO SRU
# HELLO SRU
# HELLO SRU

# %%
i = 1
while(i<=10):
  print("Hello Sreenu")
  i= i+1
# Out:
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu

# %%
i = 0
while(i<=5):
  print("Hello Sreenu")
  i= i+1
# Out:
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu
# Hello Sreenu

# %% [markdown]
# ## **Print number table**

# %%
num = 2
i = 1
while(i <= 10):
  print(f"{num} x {i} = {num * i}")
  i += 1
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
num=input("which number table yopu want to print")
num=int(num)
i = 1
while(i<=10):
  print(f"{num} x {i} = {num*i}")
  i=i+1
# Out:
# which number table yopu want to print30
# 30 x 1 = 30
# 30 x 2 = 60
# 30 x 3 = 90
# 30 x 4 = 120
# 30 x 5 = 150
# 30 x 6 = 180
# 30 x 7 = 210
# 30 x 8 = 240
# 30 x 9 = 270
# 30 x 10 = 300

# %%
num=input("which number table yopu want to print")
num=int(num)
i = 1
while(i<=10):
  print(f"{num} x {i} = {num*i}")
  if(i==5):
    break
  i=i+1
# Out:
# which number table yopu want to print30
# 30 x 1 = 30
# 30 x 2 = 60
# 30 x 3 = 90
# 30 x 4 = 120
# 30 x 5 = 150

# %% [markdown]
# ## Break statement along with while loop:
